# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="200" />
#
# #### Teoría de los Circuitos 2
#
# # Trabajo semanal 7
#
# #### Ana Nuñez

# %% [markdown]
# # Consigna
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 1. Desarrollo analítico
#
# A continuacíon se adjuntan el desarrollo analítico

# %%
from IPython.display import IFrame
IFrame("./TS7.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./TS7.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Simulacion numerica circuital Ej3 gruia
#
# Se utilizo pyfdax para corroborar los resultados:
#
# ## 3)a)
#
# ### H1(Z)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# ### H2(Z)
#
# ![image.png](attachment:image.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ## 3)b)
#
# ### H1(Z)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)
#
# ![image-9.png](attachment:image-9.png)
#
#
# ### H2(Z)
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)

# %% [markdown]
# # Simulacion Ej 2 TS7
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
